# %% [markdown]
# ![image.png](attachment:b08dff12-2894-4cfc-a308-c1f4519fac28.png)

# %%
class Solution(object):
    def defangIPaddr(self, address):
        return address.replace(".", "[.]")

obj = Solution()
print(obj.defangIPaddr("1.1.1.1"))
# Out:
# 1[.]1[.]1[.]1

# %% [markdown]
# ![image.png](attachment:9a003c61-9864-4099-aac0-7ce982cb6716.png)

# %%
class Solution(object):
    def findNumbers(self, nums):
        count = 0
        for num in nums:
            if len(str(num)) % 2 == 0:
                count += 1
        return count


obj = Solution()
print(obj.findNumbers([12,345,2,6,7896]))
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:9b3b7851-b0fd-4d58-9a36-6461fa8cf9a8.png)

# %%
class Solution(object):
    def numIdenticalPairs(self, nums):
        count = 0
        freq = {}

        for num in nums:
            if num in freq:
                count += freq[num]
                freq[num] += 1
            else:
                freq[num] = 1

        return count
obj = Solution()
print(obj.numIdenticalPairs([1,2,3,1,1,3]))
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:9c5ae650-ee24-42c8-afcd-3267b39dc54c.png)

# %%
class Solution(object):
    def smallerNumbersThanCurrent(self, nums):
        sorted_nums = sorted(nums)
        result = []

        for num in nums:
            result.append(sorted_nums.index(num))

        return result
obj = Solution()
print(obj.smallerNumbersThanCurrent([8,1,2,2,3]))
# Out:
# [4, 0, 1, 1, 3]

# %% [markdown]
# ![image.png](attachment:2172352b-9e08-4029-9ab1-7be0952454b9.png)

# %%
class Solution(object):
    def subtractProductAndSum(self, n):
        product = 1
        total = 0
        
        while n > 0:
            digit = n % 10
            product *= digit
            total += digit
            n //= 10
        
        return product - total
obj = Solution()
print(obj.subtractProductAndSum(4421))
# Out:
# 21

# %% [markdown]
# ![image.png](attachment:f97bd5e5-414c-4076-8db6-8e548b6611ae.png)

# %%
class Solution(object):
    def xorOperation(self, n, start):
        result = 0
        for i in range(n):
            result ^= start + 2 * i
        return result
obj = Solution()
print(obj.xorOperation(5,0))
# Out:
# 8
