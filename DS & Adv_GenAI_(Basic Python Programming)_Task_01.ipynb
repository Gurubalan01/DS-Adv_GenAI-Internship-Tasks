# %% [markdown]
# # 1
# ![image.png](attachment:4035d1f0-c0fc-47b4-82a2-022b2d0e631c.png)

# %%
if __name__ == '__main__':
    print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # 2
# ![image.png](attachment:f752914f-7417-4b8a-88b5-297434c04776.png)

# %%
if __name__ == '__main__':
    n = int(input().strip())
    if n % 2 != 0:
        print("Weird")
    elif n % 2 == 0 and 2 <= n <= 5:
        print("Not Weird")
    elif n % 2 == 0 and 6 <= n <= 20:
        print("Weird")
    elif n % 2 == 0 and n > 20:
        print("Not Weird")
# Out:
#  3
# Weird

# %% [markdown]
# # 3
# ![image.png](attachment:d6f0440a-dc7f-40fd-855f-d740836660de.png)

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    
    print(a + b)
    print(a - b)
    print(a * b)
# Out:
#  3
#  2
# 5
# 1
# 6

# %% [markdown]
# # 4
# ![image.png](attachment:b8d905ce-b6dd-49f3-9f87-d65af60c9f19.png)

# %%
if __name__ == '__main__':
    n = int(input())
    
    for i in range(n):
        print(i * i)
# Out:
#  5
# 0
# 1
# 4
# 9
# 16

# %% [markdown]
# # 5
# ![image.png](attachment:794784b4-9f6a-4915-ad2e-10bca72db641.png)

# %%
def is_leap(year):
    leap = False
    
    if year % 400 == 0:
        leap = True
    elif year % 100 == 0:
        leap = False
    elif year % 4 == 0:
        leap = True

    
    return leap

year = int(input())
print(is_leap(year))
# Out:
#  1990
# False

# %% [markdown]
# # 6
# ![image.png](attachment:0cdeaec3-acc8-453f-97a9-116bb542a6f9.png)

# %%
if __name__ == '__main__':
    n = int(input())
    
    for i in range(1, n + 1):
        print(i, end="")
# Out:
#  3
# 123
